# %% [markdown]
# # Question 1

# %% [markdown]
# ## Step1 : Using PCA to reduce dimension

# %%
import pandas as pd
from sklearn.decomposition import PCA

# %%
df=pd.read_csv("/Users/hanweiyu/Downloads/Assignment 2/data.csv")

# %%
df
# Out:
#                     ID_REF  GSM25349  GSM25350  GSM25356  GSM25357  GSM25358  \
# 0                1007_s_at     329.9     408.1     258.2     262.0     299.2
# 1                  1053_at     419.1     378.6     359.9     612.1     297.4
# 2                   117_at      70.8      47.9     107.9     114.3     111.2
# 3                   121_at     908.2     798.4     720.5     798.0     614.6
# 4                1255_g_at      50.9       8.0      12.9      55.4      27.3
# ...                    ...       ...       ...       ...       ...       ...
# 8788  AFFX-r2-Ec-bioC-5_at    1351.9    1015.2    2340.9     439.1    1097.6
# 8789  AFFX-r2-Ec-bioD-3_at    4456.8    3188.6    7993.1    1845.3    3985.8
# 8790  AFFX-r2-Ec-bioD-5_at    3634.6    2813.5    6777.1    1340.0    3385.2
# 8791   AFFX-r2-P1-cre-3_at   15062.4   10854.6   19995.1    6494.0   12609.5
# 8792   AFFX-r2-P1-cre-5_at   17679.5   13325.2   20964.6    7346.5   15322.4
#
# ...

# %%
df1=df.T

# %%
df1
# Out:
#                 0        1        2        3          4        5        6     \
# ID_REF     1007_s_at  1053_at   117_at   121_at  1255_g_at  1294_at  1316_at
# GSM25349       329.9    419.1     70.8    908.2       50.9    510.5    102.6
# GSM25350       408.1    378.6     47.9    798.4        8.0    575.6    107.9
# GSM25356       258.2    359.9    107.9    720.5       12.9    485.7     55.0
# GSM25357       262.0    612.1    114.3    798.0       55.4    345.3    117.2
# ...              ...      ...      ...      ...        ...      ...      ...
# GSM136724    417.699  426.201  87.6001    950.9       23.5  637.601  87.2002
# GSM136725      380.6  438.201  80.5002  666.601    40.7001  505.799  87.9999
# GSM136726      422.8    431.1     58.0  797.699       19.3  350.799  71.6001
# GSM136727    232.401    296.1    152.1  787.202    50.6999    362.3  27.8999
# GSM136729      248.3    235.1    124.6  631.299    5.69999  528.999     41.5
#
# ...

# %%
df1=df1.drop('ID_REF')

# %%
pca = PCA(n_components=2)
pca.fit(df1)
newdf1=pca.fit_transform(df1)

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.48691024 0.14706175]

# %%
import matplotlib.pyplot as plt

# %%
dd=pd.DataFrame(newdf1,columns=['CP1','CP2'])

# %%
x1=dd['CP1']
y1=dd['CP2']
plt.scatter(x1,y1)
plt.show()

# %% [markdown]
# ## Step2 : Deploying different clustering algorithm

# %% [markdown]
# ### KMeans

# %%
from sklearn.cluster import KMeans

# %%
s=[]
for i in range(1,11):
    kmeans = KMeans(n_clusters=i)
    result = kmeans.fit(df1)
    s.append(result.inertia_)

# %%
plt.plot(range(1,11),s)

# %%
#determine k = 3 using silhouette coefficient
kmeans = KMeans(n_clusters=3)
result = kmeans.fit(df1)

# %%
y = result.fit_predict(df1)

# %%
df1.shape
# Out:
# (208, 8793)

# %%
plt.scatter(newdf1[y==0,0],newdf1[y==0,1],c='purple',label='cluster1')
plt.scatter(newdf1[y==1,0],newdf1[y==1,1],c='blue',label='cluster2')
plt.scatter(newdf1[y==2,0],newdf1[y==2,1],c='green',label='cluster3')

#plt.scatter(result.cluster_centers_[:,0],result.cluster_centers_[:,1],marker='s',c='red',alpha=0.7,label='centroids')

plt.legend()
plt.show()

# %% [markdown]
# ### K-Means++

# %%
s=[]
for i in range(1,11):
    kmeans = KMeans(init='k-means++',n_clusters=i)
    result = kmeans.fit(df1)
    s.append(result.inertia_)

# %%
plt.plot(range(1,11),s)

# %%
#determine k = 3 using silhouette coefficient
kmeans = KMeans(init='k-means++',n_clusters=3)
result = kmeans.fit(df1)

# %%
y = result.fit_predict(df1)

# %%
plt.scatter(newdf1[y==0,0],newdf1[y==0,1],c='purple',label='cluster1')
plt.scatter(newdf1[y==1,0],newdf1[y==1,1],c='blue',label='cluster2')
plt.scatter(newdf1[y==2,0],newdf1[y==2,1],c='green',label='cluster3')

#plt.scatter(result.cluster_centers_[:,0],result.cluster_centers_[:,1],marker='s',c='red',alpha=0.7,label='centroids')

plt.legend()
plt.show()
#not so different from kmeans

# %% [markdown]
# ### Dendrogram

# %%
import scipy.cluster.hierarchy as sch
dend=sch.dendrogram(sch.linkage(df1,method='ward'))
plt.xlabel('patient')
plt.show()

# %%
import scipy.cluster.hierarchy as sch
dend=sch.dendrogram(sch.linkage(df1,method='complete'))
plt.xlabel('patient')
plt.show()

# %% [markdown]
# ### Agglomerative

# %%
from sklearn.cluster import AgglomerativeClustering
hc=AgglomerativeClustering(n_clusters=3,affinity='euclidean',linkage='ward')
y=hc.fit_predict(df1)

# %%
plt.scatter(newdf1[y==0,0],newdf1[y==0,1],c='purple',label='cluster1')
plt.scatter(newdf1[y==1,0],newdf1[y==1,1],c='blue',label='cluster2')
plt.scatter(newdf1[y==2,0],newdf1[y==2,1],c='green',label='cluster3')

#plt.scatter(result.cluster_centers_[:,0],result.cluster_centers_[:,1],marker='s',c='red',alpha=0.7,label='centroids')

plt.legend()
plt.show()

# %%
hc=AgglomerativeClustering(n_clusters=3,affinity='euclidean',linkage='complete')
y=hc.fit_predict(df1)

plt.scatter(newdf1[y==0,0],newdf1[y==0,1],c='purple',label='cluster1')
plt.scatter(newdf1[y==1,0],newdf1[y==1,1],c='blue',label='cluster2')
plt.scatter(newdf1[y==2,0],newdf1[y==2,1],c='green',label='cluster3')

#plt.scatter(result.cluster_centers_[:,0],result.cluster_centers_[:,1],marker='s',c='red',alpha=0.7,label='centroids')

plt.legend()
plt.show()

# %%
hc=AgglomerativeClustering(n_clusters=3,affinity='euclidean',linkage='single')
y=hc.fit_predict(df1)

plt.scatter(newdf1[y==0,0],newdf1[y==0,1],c='purple',label='cluster1')
plt.scatter(newdf1[y==1,0],newdf1[y==1,1],c='blue',label='cluster2')
plt.scatter(newdf1[y==2,0],newdf1[y==2,1],c='green',label='cluster3')

#plt.scatter(result.cluster_centers_[:,0],result.cluster_centers_[:,1],marker='s',c='red',alpha=0.7,label='centroids')

plt.legend()
plt.show()

# %%
hc=AgglomerativeClustering(n_clusters=3,affinity='euclidean',linkage='average')
y=hc.fit_predict(df1)

plt.scatter(newdf1[y==0,0],newdf1[y==0,1],c='purple',label='cluster1')
plt.scatter(newdf1[y==1,0],newdf1[y==1,1],c='blue',label='cluster2')
plt.scatter(newdf1[y==2,0],newdf1[y==2,1],c='green',label='cluster3')

#plt.scatter(result.cluster_centers_[:,0],result.cluster_centers_[:,1],marker='s',c='red',alpha=0.7,label='centroids')

plt.legend()
plt.show()

# %% [markdown]
# # Question 2

# %% [markdown]
# ## Step1 : Descriptive statistics

# %%
df2=pd.read_csv("/Users/hanweiyu/Downloads/Assignment 2/meta_data.csv")

# %%
df2
# Out:
#      Unnamed: 0 ethnicity        date   filename sex
# 0             0   Region1  2003-02-04   GSM25349   M
# 1             1   Region1  2003-02-04   GSM25350   M
# 2             2   Region1  2002-12-17   GSM25356   M
# 3             3   Region1  2003-01-30   GSM25357   M
# 4             4   Region1  2003-01-03   GSM25358   M
# ..          ...       ...         ...        ...  ..
# 203         203   Region3  2006-04-28  GSM136724   M
# 204         204   Region1  2005-02-16  GSM136725   F
# 205         205   Region1  2005-02-16  GSM136726   M
# 206         206   Region1  2005-06-10  GSM136727   M
# 207         207   Region2  2005-05-13  GSM136729   M
#
# [208 rows x 5 columns]

# %%
df1
# Out:
#               0        1        2        3        4        5        6     \
# GSM25349     329.9    419.1     70.8    908.2     50.9    510.5    102.6
# GSM25350     408.1    378.6     47.9    798.4      8.0    575.6    107.9
# GSM25356     258.2    359.9    107.9    720.5     12.9    485.7     55.0
# GSM25357     262.0    612.1    114.3    798.0     55.4    345.3    117.2
# GSM25358     299.2    297.4    111.2    614.6     27.3    668.4     54.1
# ...            ...      ...      ...      ...      ...      ...      ...
# GSM136724  417.699  426.201  87.6001    950.9     23.5  637.601  87.2002
# GSM136725    380.6  438.201  80.5002  666.601  40.7001  505.799  87.9999
# GSM136726    422.8    431.1     58.0  797.699     19.3  350.799  71.6001
# GSM136727  232.401    296.1    152.1  787.202  50.6999    362.3  27.8999
# GSM136729    248.3    235.1    124.6  631.299  5.69999  528.999     41.5
#
#               7        8     9     ...     8783     8784     8785     8786  \
# ...

# %%
df1.columns=df.T.values.tolist()[0]

# %%
df1
# Out:
#           1007_s_at  1053_at   117_at   121_at 1255_g_at  1294_at  1316_at  \
# GSM25349      329.9    419.1     70.8    908.2      50.9    510.5    102.6
# GSM25350      408.1    378.6     47.9    798.4       8.0    575.6    107.9
# GSM25356      258.2    359.9    107.9    720.5      12.9    485.7     55.0
# GSM25357      262.0    612.1    114.3    798.0      55.4    345.3    117.2
# GSM25358      299.2    297.4    111.2    614.6      27.3    668.4     54.1
# ...             ...      ...      ...      ...       ...      ...      ...
# GSM136724   417.699  426.201  87.6001    950.9      23.5  637.601  87.2002
# GSM136725     380.6  438.201  80.5002  666.601   40.7001  505.799  87.9999
# GSM136726     422.8    431.1     58.0  797.699      19.3  350.799  71.6001
# GSM136727   232.401    296.1    152.1  787.202   50.6999    362.3  27.8999
# GSM136729     248.3    235.1    124.6  631.299   5.69999  528.999     41.5
#
#            1320_at  1431_at 1438_at  ... AFFX-r2-Bs-thr-M_s_at  \
# ...

# %%
dft=pd.merge(df2,df1,how='inner',left_on='filename',right_on=df1.index)

# %%
dft
# Out:
#      Unnamed: 0 ethnicity        date   filename sex 1007_s_at  1053_at  \
# 0             0   Region1  2003-02-04   GSM25349   M     329.9    419.1
# 1             1   Region1  2003-02-04   GSM25350   M     408.1    378.6
# 2             2   Region1  2002-12-17   GSM25356   M     258.2    359.9
# 3             3   Region1  2003-01-30   GSM25357   M     262.0    612.1
# 4             4   Region1  2003-01-03   GSM25358   M     299.2    297.4
# ..          ...       ...         ...        ...  ..       ...      ...
# 203         203   Region3  2006-04-28  GSM136724   M   417.699  426.201
# 204         204   Region1  2005-02-16  GSM136725   F     380.6  438.201
# 205         205   Region1  2005-02-16  GSM136726   M     422.8    431.1
# 206         206   Region1  2005-06-10  GSM136727   M   232.401    296.1
# 207         207   Region2  2005-05-13  GSM136729   M     248.3    235.1
#
#       117_at   121_at 1255_g_at  ... AFFX-r2-Bs-thr-M_s_at  \
# ...

# %%
dfm=dft[dft['sex']=='M']

# %%
dff=dft[dft['sex']=='F']

# %%
dft['sex'].value_counts()
# Out:
# M    122
# F     86
# Name: sex, dtype: int64

# %% [markdown]
# ## Step2 : Feature selection

# %%
from sklearn.linear_model import LogisticRegression as LR
from sklearn.model_selection import cross_val_score

# %%
dft=pd.get_dummies(dft,drop_first=True,columns=['ethnicity','sex'])

# %%
dft.head()
# Out:
#    Unnamed: 0        date  filename 1007_s_at 1053_at 117_at 121_at 1255_g_at  \
# 0           0  2003-02-04  GSM25349     329.9   419.1   70.8  908.2      50.9
# 1           1  2003-02-04  GSM25350     408.1   378.6   47.9  798.4       8.0
# 2           2  2002-12-17  GSM25356     258.2   359.9  107.9  720.5      12.9
# 3           3  2003-01-30  GSM25357     262.0   612.1  114.3  798.0      55.4
# 4           4  2003-01-03  GSM25358     299.2   297.4  111.2  614.6      27.3
#
#   1294_at 1316_at  ... AFFX-r2-Ec-bioB-M_at AFFX-r2-Ec-bioC-3_at  \
# 0   510.5   102.6  ...                370.1               1353.8
# 1   575.6   107.9  ...                250.0               1032.4
# 2   485.7    55.0  ...                806.4               2539.7
# 3   345.3   117.2  ...                136.9                646.1
# 4   668.4    54.1  ...                332.3               1303.8
#
#   AFFX-r2-Ec-bioC-5_at AFFX-r2-Ec-bioD-3_at AFFX-r2-Ec-bioD-5_at  \
# ...

# %%
dft=dft.drop(['Unnamed: 0','date','filename'],axis=1)

# %%
dft.iloc[:,:-1]
# Out:
#     ethnicity 1007_s_at  1053_at   117_at   121_at 1255_g_at  1294_at  \
# 0     Region1     329.9    419.1     70.8    908.2      50.9    510.5
# 1     Region1     408.1    378.6     47.9    798.4       8.0    575.6
# 2     Region1     258.2    359.9    107.9    720.5      12.9    485.7
# 3     Region1     262.0    612.1    114.3    798.0      55.4    345.3
# 4     Region1     299.2    297.4    111.2    614.6      27.3    668.4
# ..        ...       ...      ...      ...      ...       ...      ...
# 203   Region3   417.699  426.201  87.6001    950.9      23.5  637.601
# 204   Region1     380.6  438.201  80.5002  666.601   40.7001  505.799
# 205   Region1     422.8    431.1     58.0  797.699      19.3  350.799
# 206   Region1   232.401    296.1    152.1  787.202   50.6999    362.3
# 207   Region2     248.3    235.1    124.6  631.299   5.69999  528.999
#
#      1316_at  1320_at  1431_at  ... AFFX-r2-Bs-thr-M_s_at  \
# 0      102.6      9.3     43.6  ...                  81.3
# ...

# %%
from sklearn.feature_selection import SelectFromModel

# %%
LR_ = LR(solver="saga",C=0.9,random_state=1)
cross_val_score(LR_,dft.iloc[:,:-1],dft.iloc[:,-1],cv=10).mean()
X_embedded = SelectFromModel(LR_,norm_order=1).fit_transform(dft.iloc[:,:-1],dft.iloc[:,-1])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# ...

# %%
X_embedded.shape
# Out:
# (208, 1921)

# %%
cross_val_score(LR_,X_embedded,dft.iloc[:,-1],cv=10).mean()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:328: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# ...

# %%
dft.head()
# Out:
#   1007_s_at 1053_at 117_at 121_at 1255_g_at 1294_at 1316_at 1320_at 1431_at  \
# 0     329.9   419.1   70.8  908.2      50.9   510.5   102.6     9.3    43.6
# 1     408.1   378.6   47.9  798.4       8.0   575.6   107.9    70.7    37.0
# 2     258.2   359.9  107.9  720.5      12.9   485.7    55.0    10.1    23.0
# 3     262.0   612.1  114.3  798.0      55.4   345.3   117.2    27.0    58.0
# 4     299.2   297.4  111.2  614.6      27.3   668.4    54.1     5.1    36.3
#
#   1438_at  ... AFFX-r2-Ec-bioB-M_at AFFX-r2-Ec-bioC-3_at AFFX-r2-Ec-bioC-5_at  \
# 0    48.5  ...                370.1               1353.8               1351.9
# 1    27.8  ...                250.0               1032.4               1015.2
# 2    58.2  ...                806.4               2539.7               2340.9
# 3    48.7  ...                136.9                646.1                439.1
# 4    10.9  ...                332.3               1303.8               1097.6
#
# ...

# %%
from scipy.stats import ranksums

# %%
klist=[]
for k in range(0,8796):
    md=dft[dft['sex_M']==1].iloc[:,k]
    fd=dft[dft['sex_M']==0].iloc[:,k]
    if ranksums(md,fd).pvalue <= 0.01:
        klist.append(k)

# %%
len(klist)
# Out:
# 494

# %%
import numpy as np

# %%
l=[]
l=klist-np.ones(494)

# %%
newdf=dft.iloc[:,l]

# %%
newdf.head()
# Out:
#   200012_x_at 200018_at 200028_s_at 200030_s_at 200053_at 200055_at  \
# 0     25402.5   22915.6      2805.7     14468.0    2330.7    3863.6
# 1     24861.3   19068.3      3064.9     13277.6    2810.8    4447.5
# 2     19184.1   24882.4      3634.2      8859.0    1178.8    3139.2
# 3     15784.5   17120.4      3806.6      8783.1    1179.9    3090.1
# 4     12928.7   20477.0      3317.2      8633.1     977.3    3338.5
#
#   200067_x_at 200070_at 200075_s_at 200081_s_at  ... 222123_s_at 222239_s_at  \
# 0      1092.1     502.1      1999.9     30502.0  ...        15.6       349.8
# 1      1392.5     330.9      2020.3     27351.3  ...        44.2       249.6
# 2      1219.2     483.2      1892.7     22930.5  ...        68.6       389.3
# 3      1576.8     518.3      1857.4     16697.9  ...        65.0       365.8
# 4      1532.3     612.7      1684.1     18589.7  ...        41.5       373.1
#
#   243_g_at 32723_at 33304_at 33814_at 36499_at 38241_at 38964_r_at  \
# ...

# %% [markdown]
# ## Step3 : Logistics Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score

# %%
l1 = []
l1test = []
l2 = []
l2test = []

Xtrain, Xtest, Ytrain, Ytest = train_test_split(newdf,dft.iloc[:,-1],test_size=0.3,random_state=420)

for i in np.arange(1,201,10):
    lrl1 = LR(penalty="l1",solver="liblinear",C=0.9,max_iter=i)
    lrl1 = lrl1.fit(Xtrain,Ytrain)
    l1.append(accuracy_score(lrl1.predict(Xtrain),Ytrain))
    l1test.append(accuracy_score(lrl1.predict(Xtest),Ytest))
    
    lrl2 = LR(penalty="l2",solver="liblinear",C=0.9,max_iter=i)
    lrl2 = lrl2.fit(Xtrain,Ytrain)
    l2.append(accuracy_score(lrl2.predict(Xtrain),Ytrain))
    l2test.append(accuracy_score(lrl2.predict(Xtest),Ytest))
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# ...

# %%
graph = [l1,l1test,l2,l2test]
color = ["red","blue","black","gray"]
label = ["L1","L1test","L2","L2test"]
plt.figure(figsize=(20,5))
for i in range(len(graph)):
    plt.plot(np.arange(1,201,10),graph[i],color[i],label=label[i])
plt.legend()
plt.xticks(np.arange(1,201,10))
plt.show()

# %%
l1 = []
l1test = []
l2 = []
l2test = []

Xtrain, Xtest, Ytrain, Ytest = train_test_split(newdf,dft.iloc[:,-1],test_size=0.3,random_state=420)

for i in np.arange(1,201,10):
    lrl1 = LR(penalty="l1",solver="liblinear",C=0.9,max_iter=i)
    lrl1 = lrl1.fit(Xtrain,Ytrain)
    l1.append(f1_score(lrl1.predict(Xtrain),Ytrain))
    l1test.append(f1_score(lrl1.predict(Xtest),Ytest))
    
    lrl2 = LR(penalty="l2",solver="liblinear",C=0.9,max_iter=i)
    lrl2 = lrl2.fit(Xtrain,Ytrain)
    l2.append(f1_score(lrl2.predict(Xtrain),Ytrain))
    l2test.append(f1_score(lrl2.predict(Xtest),Ytest))
    
graph = [l1,l1test,l2,l2test]
color = ["red","blue","black","gray"]
label = ["L1","L1test","L2","L2test"]
plt.figure(figsize=(20,5))
for i in range(len(graph)):
    plt.plot(np.arange(1,201,10),graph[i],color[i],label=label[i])
plt.legend()
plt.xticks(np.arange(1,201,10))
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# ...

# %%
l1 = []
l1test = []
l2 = []
l2test = []

Xtrain, Xtest, Ytrain, Ytest = train_test_split(newdf,dft.iloc[:,-1],test_size=0.3,random_state=420)

for i in np.arange(1,201,10):
    lrl1 = LR(penalty="l1",solver="liblinear",C=0.9,max_iter=i)
    lrl1 = lrl1.fit(Xtrain,Ytrain)
    l1.append(roc_auc_score(lrl1.predict(Xtrain),Ytrain))
    l1test.append(roc_auc_score(lrl1.predict(Xtest),Ytest))
    
    lrl2 = LR(penalty="l2",solver="liblinear",C=0.9,max_iter=i)
    lrl2 = lrl2.fit(Xtrain,Ytrain)
    l2.append(roc_auc_score(lrl2.predict(Xtrain),Ytrain))
    l2test.append(roc_auc_score(lrl2.predict(Xtest),Ytest))
    
graph = [l1,l1test,l2,l2test]
color = ["red","blue","black","gray"]
label = ["L1","L1test","L2","L2test"]
plt.figure(figsize=(20,5))
for i in range(len(graph)):
    plt.plot(np.arange(1,201,10),graph[i],color[i],label=label[i])
plt.legend()
plt.xticks(np.arange(1,201,10))
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# ...

# %%
l1 = []
l1test = []
l2 = []
l2test = []

Xtrain, Xtest, Ytrain, Ytest = train_test_split(newdf,dft.iloc[:,-1],test_size=0.3,random_state=420)

for i in np.arange(1,21,1):
    lrl1 = LR(penalty="l1",solver="liblinear",C=0.9,max_iter=i)
    lrl1 = lrl1.fit(Xtrain,Ytrain)
    l1.append(accuracy_score(lrl1.predict(Xtrain),Ytrain))
    l1test.append(accuracy_score(lrl1.predict(Xtest),Ytest))
    
    lrl2 = LR(penalty="l2",solver="liblinear",C=0.9,max_iter=i)
    lrl2 = lrl2.fit(Xtrain,Ytrain)
    l2.append(accuracy_score(lrl2.predict(Xtrain),Ytrain))
    l2test.append(accuracy_score(lrl2.predict(Xtest),Ytest))

graph = [l1,l1test,l2,l2test]
color = ["red","blue","black","gray"]
label = ["L1","L1test","L2","L2test"]

for i in range(len(graph)):
    plt.plot(np.arange(1,21,1),graph[i],color[i],label=label[i])
plt.legend()
plt.xticks(np.arange(1,21,1))
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# ...

# %%
l1 = []
l1test = []
l2 = []
l2test = []

Xtrain, Xtest, Ytrain, Ytest = train_test_split(newdf,dft.iloc[:,-1],test_size=0.3,random_state=420)

for i in np.arange(1,21,1):
    lrl1 = LR(penalty="l1",solver="liblinear",C=0.9,max_iter=i)
    lrl1 = lrl1.fit(Xtrain,Ytrain)
    l1.append(f1_score(lrl1.predict(Xtrain),Ytrain))
    l1test.append(f1_score(lrl1.predict(Xtest),Ytest))
    
    lrl2 = LR(penalty="l2",solver="liblinear",C=0.9,max_iter=i)
    lrl2 = lrl2.fit(Xtrain,Ytrain)
    l2.append(f1_score(lrl2.predict(Xtrain),Ytrain))
    l2test.append(f1_score(lrl2.predict(Xtest),Ytest))

graph = [l1,l1test,l2,l2test]
color = ["red","blue","black","gray"]
label = ["L1","L1test","L2","L2test"]

for i in range(len(graph)):
    plt.plot(np.arange(1,21,1),graph[i],color[i],label=label[i])
plt.legend()
plt.xticks(np.arange(1,21,1))
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# ...

# %%
l1 = []
l1test = []
l2 = []
l2test = []

Xtrain, Xtest, Ytrain, Ytest = train_test_split(newdf,dft.iloc[:,-1],test_size=0.3,random_state=420)

for i in np.arange(1,21,1):
    lrl1 = LR(penalty="l1",solver="liblinear",C=0.9,max_iter=i)
    lrl1 = lrl1.fit(Xtrain,Ytrain)
    l1.append(roc_auc_score(lrl1.predict(Xtrain),Ytrain))
    l1test.append(roc_auc_score(lrl1.predict(Xtest),Ytest))
    
    lrl2 = LR(penalty="l2",solver="liblinear",C=0.9,max_iter=i)
    lrl2 = lrl2.fit(Xtrain,Ytrain)
    l2.append(roc_auc_score(lrl2.predict(Xtrain),Ytrain))
    l2test.append(roc_auc_score(lrl2.predict(Xtest),Ytest))

graph = [l1,l1test,l2,l2test]
color = ["red","blue","black","gray"]
label = ["L1","L1test","L2","L2test"]

for i in range(len(graph)):
    plt.plot(np.arange(1,21,1),graph[i],color[i],label=label[i])
plt.legend()
plt.xticks(np.arange(1,21,1))
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# ...

# %%
from sklearn.metrics import roc_curve

# %%
pd.DataFrame(lrl1.predict_proba(Xtrain)).iloc[:,1].values.tolist()
# Out:
# [0.9856286844525126,
#  0.007736391916953873,
#  0.0038650712871981492,
#  0.9807568604320672,
#  0.9931527271983648,
#  0.01721494203383387,
#  0.9688111819507541,
#  0.037006286793770896,
#  0.999992742802157,
#  0.9955980376409399,
#  0.9967300009599149,
#  0.012316944193343709,
#  0.9832259406781557,
#  0.004168891315294999,
#  0.9994405928358951,
#  0.9994760446110632,
#  0.9900215349614575,
#  0.0020543207080114517,
#  0.9959131232249411,
#  0.012431345728527735,
#  0.02210331363979179,
#  0.9998844205234892,
#  0.9880692215998153,
#  0.9974769309402257,
#  0.9986912335503968,
#  0.978346954961811,
#  0.01782817314370291,
#  0.9879591364523577,
#  0.0002609986925362041,
#  0.984736366054413,
#  0.0025326152187349,
#  0.9924968918445737,
#  0.0103232705084402,
#  0.9650749225271138,
#  0.021157939651649887,
#  0.9909206985748229,
#  0.9821858233450366,
#  0.9622447097561061,
#  0.00040546182758743356,
#  0.0037470118842327523,
#  0.999798060438585,
#  0.9999505684479593,
# ...

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(newdf,dft.iloc[:,-1],test_size=0.3,random_state=420)

lrl1 = LR(penalty="l1",solver="liblinear",C=0.9,max_iter=7)
lrl1 = lrl1.fit(Xtrain,Ytrain)

fpr, tpr, thresholds = roc_curve(Ytest,lrl1.predict_proba(Xtest)[:,1])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %%
from sklearn.metrics import auc
roc_auc = auc(fpr, tpr)
import matplotlib.pyplot as plt
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.show()

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(newdf,dft.iloc[:,-1],test_size=0.3,random_state=420)

lrl1 = LR(penalty="l1",solver="liblinear",C=0.9,max_iter=6)
lrl1 = lrl1.fit(Xtrain,Ytrain)

fpr, tpr, thresholds = roc_curve(Ytest,lrl1.predict_proba(Xtest)[:,1])

from sklearn.metrics import auc
roc_auc = auc(fpr, tpr)
import matplotlib.pyplot as plt
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(newdf,dft.iloc[:,-1],test_size=0.3,random_state=420)

lrl1 = LR(penalty="l1",solver="liblinear",C=0.9,max_iter=8)
lrl1 = lrl1.fit(Xtrain,Ytrain)

fpr, tpr, thresholds = roc_curve(Ytest,lrl1.predict_proba(Xtest)[:,1])

from sklearn.metrics import auc
roc_auc = auc(fpr, tpr)
import matplotlib.pyplot as plt
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
